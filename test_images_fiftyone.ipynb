# %%
# Import fiftyone
import fiftyone as fo

# Import data
# A name for the dataset
name = "sample_images"

# The directory containing the dataset to import
dataset_dir = "/Users/michaelheilig/GIT/OTC/OTLabels/data/image_data"

dataset = fo.Dataset.from_dir(
    dataset_dir=dataset_dir,
    dataset_type=fo.types.ImageDirectory,
    name=name,
    max_samples=200,
    shuffle=True,
)

# Add some tags
dataset.tags = ["test", "sample_images"]
dataset.save()
# Out:
#  100% |█████████████████| 200/200 [26.6ms elapsed, 0s remaining, 7.5K samples/s]

# %%
print(dataset)
# Out:
# Name:        sample_images
# Media type:  image
# Num samples: 200
# Persistent:  False
# Tags:        ['test', 'sample_images']
# Sample fields:
#     id:       fiftyone.core.fields.ObjectIdField
#     filepath: fiftyone.core.fields.StringField
#     tags:     fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)

# %%
# Launch app
session = fo.launch_app(dataset)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed:focus {
#   outline: none;
# }
# #fooverlay-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed">
#    <div id="fooverlay-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed" style="display: none;">
#       <button id="foactivate-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed" >Activate</button>
#    </div>
#    <img src='data:image/png;base64,...' style="width: 100%; max-width: 1398px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed");
#      var overlay = document.getElementById("fooverlay-b3cc6467-97bc-49ff-b8ac-d9d1a7271aed");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "b3cc6467-97bc-49ff-b8ac-d9d1a7271aed" },
#               subscription: "b3cc6467-97bc-49ff-b8ac-d9d1a7271aed"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>
